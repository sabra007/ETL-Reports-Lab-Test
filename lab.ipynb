# %% [markdown]
# - How do trends in the US compare over time? Ray
# - How do trends in the world change over time? Annie
# - How do income groups affect parliament trends over time? Abbey
# - Taking income group into consideration, how do parliament trends differ between countries categorized as higher vs. lower income groups? Scott
# - What does the data look like for 2020 for all countries? Regina
# - What does the data look like for 2001 for all countries? Lindsey

# %%
import pandas as pd

# %%
proportion_of_seats = pd.read_csv('data/API_SG.GEN.PARL.ZS_DS2_en_csv_v2_3469491.csv', skiprows=4)
meta = pd.read_csv('data/Metadata_Country_API_SG.GEN.PARL.ZS_DS2_en_csv_v2_3469491.csv')

# %%
year_list = ["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996"]
proportion_of_seats.drop(year_list, axis=1, inplace=True)
proportion_of_seats.dropna(inplace=True,axis=0,thresh=5)

# %%
meta.drop(["Region","SpecialNotes","TableName", "Unnamed: 5"], axis=1, inplace=True)
meta.dropna(inplace=True,axis=0)

# %%
merged = proportion_of_seats.merge(meta, how='inner', on='Country Code')

# %%
merged
# Out:
#              Country Name Country Code  \
# 0             Afghanistan          AFG
# 1                  Angola          AGO
# 2                 Albania          ALB
# 3                 Andorra          AND
# 4    United Arab Emirates          ARE
# ..                    ...          ...
# 187                 Samoa          WSM
# 188           Yemen, Rep.          YEM
# 189          South Africa          ZAF
# 190                Zambia          ZMB
# 191              Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  \
# 0    Proportion of seats held by women in national ...  SG.GEN.PARL.ZS
# 1    Proportion of seats held by women in national ...  SG.GEN.PARL.ZS
# 2    Proportion of seats held by women in national ...  SG.GEN.PARL.ZS
# 3    Proportion of seats held by women in national ...  SG.GEN.PARL.ZS
# 4    Proportion of seats held by women in national ...  SG.GEN.PARL.ZS
# ...
